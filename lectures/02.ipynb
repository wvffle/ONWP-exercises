# %% [markdown]
# Hello, I'm an example Jupyter Notebook!

# %%
from sympy import *
init_printing()

# %%
x = symbols('x')

f = x ** 3 / (x ** 2 - 1)


plot(f, (x, -5, 5), ylim=[-5, 5])
plot(diff(f), (x, -2, 2), ylim=[-5, 5])
plot(diff(diff(f)), ylim=[-5, 5])

solve(diff(diff(f)))
# Out:
# [0, -√3⋅ⅈ, √3⋅ⅈ]
